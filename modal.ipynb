# %%
import math as mn
a=10
b=19
c=mn.sum(3.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       2 a=10
#       3 b=19
# ----> 4 c=mn.sum(3.5)
#
# AttributeError: module 'math' has no attribute 'sum'
